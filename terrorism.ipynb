# %%
import polars as pl

# %% [markdown]
# ###

# %%
"""
Polars expects UTF-8 text by default. The dataset file contains invalid UTF-8 characters.
We use:
    "utf8-lossy":
        - Tries to decode as UTF-8
        - Replaces invalid characters instead of crashing
    
    "ignore_errors":
        This skips bad rows instead of failing the entire load. It is useful when:
            - A row has too many/few columns
            - A value can’t be parsed into the inferred type
            - There are malformed quotes or delimiters

        Tradeoff is some rows maybe dropped silently.
    
    "low_memory":
        What it does:
            Reduces memory usage during CSV parsing
            Polars processes the file in smaller chunks
    
        Why it matters
            The dataset is large with hundreds of thousands of rows and many text columns
    
        This flag:
            - Uses less RAM
            - Slightly slower
            - Safer on laptops / limited-memory machines
"""

df = pl.read_csv(
    'data/global-terrorism.csv', 
    encoding="utf8-lossy", 
    ignore_errors=True,
    low_memory=True,
    row_index_name="ID",
    row_index_offset=1,
)

# %% [markdown]
# ### Count the first rows in the dataset

# %%
df.head()
# Out:
# shape: (5, 136)
# ┌─────┬──────────────┬───────┬────────┬───┬──────────┬──────────┬─────────┬─────────┐
# │ ID  ┆ eventid      ┆ iyear ┆ imonth ┆ … ┆ INT_IDEO ┆ INT_MISC ┆ INT_ANY ┆ related │
# │ --- ┆ ---          ┆ ---   ┆ ---    ┆   ┆ ---      ┆ ---      ┆ ---     ┆ ---     │
# │ u32 ┆ i64          ┆ i64   ┆ i64    ┆   ┆ i64      ┆ i64      ┆ i64     ┆ str     │
# ╞═════╪══════════════╪═══════╪════════╪═══╪══════════╪══════════╪═════════╪═════════╡
# │ 1   ┆ 197000000001 ┆ 1970  ┆ 7      ┆ … ┆ 0        ┆ 0        ┆ 0       ┆ null    │
# │ 2   ┆ 197000000002 ┆ 1970  ┆ 0      ┆ … ┆ 1        ┆ 1        ┆ 1       ┆ null    │
# │ 3   ┆ 197001000001 ┆ 1970  ┆ 1      ┆ … ┆ -9       ┆ 1        ┆ 1       ┆ null    │
# │ 4   ┆ 197001000002 ┆ 1970  ┆ 1      ┆ … ┆ -9       ┆ 1        ┆ 1       ┆ null    │
# │ 5   ┆ 197001000003 ┆ 1970  ┆ 1      ┆ … ┆ -9       ┆ 1        ┆ 1       ┆ null    │
# └─────┴──────────────┴───────┴────────┴───┴──────────┴──────────┴─────────┴─────────┘

# %% [markdown]
# ### Last rows in the dataset

# %%
df.tail()
# Out:
# shape: (5, 136)
# ┌────────┬──────────────┬───────┬────────┬───┬──────────┬──────────┬─────────┬─────────┐
# │ ID     ┆ eventid      ┆ iyear ┆ imonth ┆ … ┆ INT_IDEO ┆ INT_MISC ┆ INT_ANY ┆ related │
# │ ---    ┆ ---          ┆ ---   ┆ ---    ┆   ┆ ---      ┆ ---      ┆ ---     ┆ ---     │
# │ u32    ┆ i64          ┆ i64   ┆ i64    ┆   ┆ i64      ┆ i64      ┆ i64     ┆ str     │
# ╞════════╪══════════════╪═══════╪════════╪═══╪══════════╪══════════╪═════════╪═════════╡
# │ 181687 ┆ 201712310022 ┆ 2017  ┆ 12     ┆ … ┆ 0        ┆ 0        ┆ 0       ┆ null    │
# │ 181688 ┆ 201712310029 ┆ 2017  ┆ 12     ┆ … ┆ -9       ┆ 1        ┆ 1       ┆ null    │
# │ 181689 ┆ 201712310030 ┆ 2017  ┆ 12     ┆ … ┆ 0        ┆ 0        ┆ 0       ┆ null    │
# │ 181690 ┆ 201712310031 ┆ 2017  ┆ 12     ┆ … ┆ -9       ┆ 0        ┆ -9      ┆ null    │
# │ 181691 ┆ 201712310032 ┆ 2017  ┆ 12     ┆ … ┆ -9       ┆ 0        ┆ -9      ┆ null    │
# └────────┴──────────────┴───────┴────────┴───┴──────────┴──────────┴─────────┴─────────┘

# %% [markdown]
# ### Count total rows and columns in the dataset

# %%
df.shape
# Out:
# (181691, 136)

# %%
df.null_count().sum()
# Out:
# shape: (1, 136)
# ┌─────┬─────────┬───────┬────────┬───┬──────────┬──────────┬─────────┬─────────┐
# │ ID  ┆ eventid ┆ iyear ┆ imonth ┆ … ┆ INT_IDEO ┆ INT_MISC ┆ INT_ANY ┆ related │
# │ --- ┆ ---     ┆ ---   ┆ ---    ┆   ┆ ---      ┆ ---      ┆ ---     ┆ ---     │
# │ u32 ┆ u32     ┆ u32   ┆ u32    ┆   ┆ u32      ┆ u32      ┆ u32     ┆ u32     │
# ╞═════╪═════════╪═══════╪════════╪═══╪══════════╪══════════╪═════════╪═════════╡
# │ 0   ┆ 0       ┆ 0     ┆ 0      ┆ … ┆ 0        ┆ 0        ┆ 0       ┆ 156653  │
# └─────┴─────────┴───────┴────────┴───┴──────────┴──────────┴─────────┴─────────┘

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### Data filtering

# %%
query = df.filter(pl.col("suicide") == 3).shape
query
# Out:
# (0, 136)

# %% [markdown]
# ### Drop null values

# %%
df = df.drop_nulls(["longitude", "latitude"])

# %% [markdown]
# ### Confirm if null values have been dropped succesfully

# %%
df.null_count()

# %%
selected_data = df.select([
    "iyear",
    "imonth",
    "country_txt",
    "region_txt",
    "provstate",
    "latitude",
    "longitude",
    
]).drop_nulls([
    "longitude",
    "latitude",
    "provstate",
])

selected_data.null_count()
